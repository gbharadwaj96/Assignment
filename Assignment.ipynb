# %%
import requests

def get_weather(date):
    response = requests.get(f"https://samples.openweathermap.org/data/2.5/forecast/hourly?q=London,us&appid=b6907d289e10d714a6e88b30761fae22")
    data = response.json()
    for entry in data["list"]:
        if entry["dt_txt"].startswith(date):
            print(f"Temperature on {date}: {entry['main']['temp']}°C")
            break
    else:
        print("Date not found in the forecast.")

def get_wind_speed(date):
    response = requests.get(f"https://samples.openweathermap.org/data/2.5/forecast/hourly?q=London,us&appid=b6907d289e10d714a6e88b30761fae22")
    data = response.json()
    for entry in data["list"]:
        if entry["dt_txt"].startswith(date):
            print(f"Wind Speed on {date}: {entry['wind']['speed']} m/s")
            break
    else:
        print("Date not found in the forecast.")

def get_pressure(date):
    response = requests.get(f"https://samples.openweathermap.org/data/2.5/forecast/hourly?q=London,us&appid=b6907d289e10d714a6e88b30761fae22")
    data = response.json()
    for entry in data["list"]:
        if entry["dt_txt"].startswith(date):
            print(f"Pressure on {date}: {entry['main']['pressure']} hPa")
            break
    else:
        print("Date not found in the forecast.")

if __name__ == "__main__":
    while True:
        print("Menu:")
        print("1. Get weather")
        print("2. Get Wind Speed")
        print("3. Get Pressure")
        print("0. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            date = input("Enter the date (YYYY-MM-DD): ")
            get_weather(date)
        elif choice == "2":
            date = input("Enter the date (YYYY-MM-DD): ")
            get_wind_speed(date)
        elif choice == "3":
            date = input("Enter the date (YYYY-MM-DD): ")
            get_pressure(date)
        elif choice == "0":
            print("Exiting the program.")
            break
        else:
            print("Invalid choice. Please try again.")
# Out:
# Menu:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice: 1
# Enter the date (YYYY-MM-DD): 2023-07-25
# Date not found in the forecast.
# Menu:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice: 2
# Enter the date (YYYY-MM-DD): 2023-07-24
# Date not found in the forecast.
# Menu:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice: 3
# Enter the date (YYYY-MM-DD): 2023-05-22
# Date not found in the forecast.
# Menu:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice: 1
# Enter the date (YYYY-MM-DD): 2019-03-28
# Temperature on 2019-03-28: 276.081°C
# Menu:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice: 2
# Enter the date (YYYY-MM-DD): 2019-03-27
# Wind Speed on 2019-03-27: 1.6 m/s
# Menu:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice: 3
# Enter the date (YYYY-MM-DD): 2019-03-28
# Pressure on 2019-03-28: 1035.227 hPa
# Menu:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
